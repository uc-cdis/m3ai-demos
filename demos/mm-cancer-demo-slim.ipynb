# %% [markdown]
# # Multimodal Cancer Modeling in the Age of Foundation Model Embeddings
# ### Steven Song\*, Morgan Borjigin-Wang\*, Irene R. Madejski, Robert L. Grossman
#
# \* Equal contribution
#
# Read our paper here: https://arxiv.org/abs/2505.07683
#
# ***
#
# The Cancer Genome Atlas (TCGA) has enabled novel discoveries and served as a large-scale reference dataset in cancer through its harmonized genomics, clinical, and imaging data. Numerous prior studies have developed bespoke deep learning models over TCGA for tasks such as cancer survival prediction. A modern paradigm in biomedical deep learning is the development of foundation models (FMs) to derive feature embeddings agnostic to a specific modeling task. Biomedical text especially has seen growing development of FMs. While TCGA contains free-text data as pathology reports, these have been historically underutilized.
#
# * **We investigate the ability to train classical machine learning models over multimodal, zero-shot FM embeddings of cancer data.**
# * We demonstrate the ease and additive effect of multimodal fusion, outperforming unimodal models.
# * Overall, we propose a simple, modernized approach to multimodal cancer modeling using FM embeddings.

# %% [markdown]
# ### Overview
#
# <img src="https://raw.githubusercontent.com/StevenSong/multimodal-cancer-modeling/refs/heads/main/overview.png" alt="conceptual overview figure" width="50%"/>
#
# Conceptually, the proposed framework does late fusion of unimodal models trained over their respective embeddings. Specifically, we use:
# * BulkRNABert ([Gélard et al. 2025)](https://proceedings.mlr.press/v259/gelard25a.html)) for RNA-seq data
# * UNI2-h ([Chen et al. 2024](https://www.nature.com/articles/s41591-024-02857-3)) for histology data
# * BioMistral ([Labrak et al. 2024](https://aclanthology.org/2024.findings-acl.348/)) for pathology report data (summarized by Llama-3.1-8B-Instruct ([Grattafiori et al. 2024](https://arxiv.org/abs/2407.21783)))
#
# We can specifically break down the required steps for our approach as follows:
# 1. Pull TCGA-LUAD embeddings
# 1. Pull TCGA-LUAD metadata
# 1. Merge embeddings and metadata
# 1. Prepare experiments
# 1. Train unimodal models
# 1. Train multimodal model
# 1. Evaluate models

# %%
# !pip install h5py pandas numpy tqdm pqdm scikit-learn scikit-survival jupyterlab ipywidgets jsonrpcclient gen3
# Out:
# Requirement already satisfied: h5py in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (3.14.0)
# Requirement already satisfied: pandas in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: numpy in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: tqdm in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (4.67.1)
# Requirement already satisfied: pqdm in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: scikit-learn in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: scikit-survival in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (0.23.1)
# Requirement already satisfied: jupyterlab in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (4.5.2)
# Requirement already satisfied: ipywidgets in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (8.1.8)
# Requirement already satisfied: jsonrpcclient in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (4.0.3)
# Requirement already satisfied: gen3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (4.27.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pandas) (2025.3)
# Requirement already satisfied: bounded-pool-executor in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pqdm) (0.0.3)
# Requirement already satisfied: typing-extensions in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pqdm) (4.15.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: ecos in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from scikit-survival) (2.0.14)
# Requirement already satisfied: numexpr in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from scikit-survival) (2.10.2)
# Requirement already satisfied: osqp!=0.6.0,!=0.6.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from scikit-survival) (1.0.5)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (8.7.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (6.31.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (25.0)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (80.9.0)
# Requirement already satisfied: tomli>=1.2.2 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (2.4.0)
# Requirement already satisfied: tornado>=6.2.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (6.5.4)
# Requirement already satisfied: traitlets in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.12.1)
# Requirement already satisfied: certifi in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.32.5)
# Requirement already satisfied: comm>=0.1.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: aiofiles in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (25.1.0)
# Requirement already satisfied: aiohttp in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (3.13.3)
# Requirement already satisfied: backoff in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (1.11.1)
# Requirement already satisfied: cdislogging<2.0.0,>=1.1.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (1.1.1)
# Requirement already satisfied: click in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (8.1.8)
# Requirement already satisfied: dataclasses-json<=0.5.9 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (0.5.9)
# Requirement already satisfied: drsclient>=0.3.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (0.3.2)
# Requirement already satisfied: gen3users in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (1.1.1)
# Requirement already satisfied: humanfriendly in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (10.0)
# Requirement already satisfied: indexclient<3.0.0,>=2.3.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (2.3.1)
# Requirement already satisfied: pypfb>=0.5.33 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (0.6.2)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (6.0.3)
# Requirement already satisfied: urllib3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (2.6.3)
# Requirement already satisfied: xmltodict<0.14.0,>=0.13.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from gen3) (0.13.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from dataclasses-json<=0.5.9->gen3) (3.26.2)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from dataclasses-json<=0.5.9->gen3) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from dataclasses-json<=0.5.9->gen3) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (3.4.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: asyncio<4.0.0,>=3.4.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from drsclient>=0.3.0->gen3) (3.4.3)
# Requirement already satisfied: zipp>=3.20 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyterlab) (3.23.0)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.19)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.2.1)
# Requirement already satisfied: decorator in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack-data in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-core->jupyterlab) (4.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: dictionaryutils>=3.4.8 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pypfb>=0.5.33->gen3) (3.5.1)
# Requirement already satisfied: fastavro>=1.11.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pypfb>=0.5.33->gen3) (1.12.1)
# Requirement already satisfied: gen3dictionary>=2.0.3 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from pypfb>=0.5.33->gen3) (2.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from aiohttp->gen3) (1.22.0)
# Requirement already satisfied: six>=1.5 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<=0.5.9->gen3) (1.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.0)
# Requirement already satisfied: pycparser in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.8.1)
# Requirement already satisfied: arrow>=0.15.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
import json
import requests
from requests.adapters import HTTPAdapter, Retry
from io import StringIO
from typing import Optional

import pandas as pd
import numpy as np
from tqdm import tqdm
from pqdm.threads import pqdm
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import concordance_index_censored
from jsonrpcclient import request, parse_json, Ok, Error
from gen3.auth import Gen3Auth

# %% [markdown]
# #### Pull TCGA Embeddings
# This retrieves embeddings using the AI commons embedding service!

# %%
# Some helpers for sending API requests to the commons
auth = Gen3Auth()
session = requests.Session()

retry_strategy = Retry(
    total=5,
    backoff_factor=0.1,
    status_forcelist=[429, 500, 502, 503, 504],
)

adapter = HTTPAdapter(max_retries=retry_strategy)
session.mount("https://", adapter)

# It's ongoing work to enable batch download so for now,
# use multithreading to parallelize requests
def query(guid):
    response = session.get(
        f"https://m3aicommons.org/user/data/download/{guid}",
        auth=auth,
    )
    response.raise_for_status()
    return response.json()["url"]

expr_embs = dict()
hist_embs = dict()
text_embs = dict()

for fpath, embs, do_upper in [
    ("manifests/expr-luad.json", expr_embs, False),
    ("manifests/hist-luad.json", hist_embs, False),
    ("manifests/summ-luad.json", text_embs, True),
]:
    with open(fpath, "r") as f:
        guids = [x["guid"] for x in json.load(f)]
    temp = pqdm(guids, query, n_jobs=40)
    for x in tqdm(temp):
        fid = x["file_id"]
        if do_upper:
            # Some modalities need uppercased keys, this is an artifact of 
            # upstream data preprocessing mismatch (from other research groups)
            fid = fid.upper()
        embs[fid] = np.asarray(json.loads(x["embedding"]))
# Out:
# QUEUEING TASKS | :   0%|          | 0/439 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/439 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/439 [00:00<?, ?it/s]
# 100%|██████████| 439/439 [00:00<00:00, 13523.65it/s]
# QUEUEING TASKS | :   0%|          | 0/433 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/433 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/433 [00:00<?, ?it/s]
# 100%|██████████| 433/433 [00:00<00:00, 3182.37it/s]
# QUEUEING TASKS | :   0%|          | 0/488 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/488 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/488 [00:00<?, ?it/s]
# 100%|██████████| 488/488 [00:00<00:00, 1225.58it/s]

# %% [markdown]
# #### Pull TCGA Metadata
#
# In our embedding service, the only metadata we store with the embeddings is the filename. This is done to prevent extensive duplication of metadata columns from the GDC. We can use the GDC API itself to get a mapping of the filenames to other metadata, such as case ID and survival outcomes.
#
# Here, we also demo using the GDC Cohort Copilot as an MCP tool to construct GDC cohort filters. Ideally this would be done using an LLM, however we can also manually use the tool! This allows us to more easily construct the aforementioned metadata mappings.

# %%
endpoint = "https://gdc-cohort-copilot.m3aicommons.org/gradio_api/mcp/"
headers = {"Accept": "application/json, text/event-stream"}

# helper to parse the SSE-formatted response from the MCP server
def parse_sse(response):
    jsonrpc_str = response.text.split("\n", 1)[1].replace("data: ", "", 1)
    parsed = parse_json(jsonrpc_str)
    if isinstance(parsed, Ok):
        return parsed.result
    elif isinstance(parsed, Error):
        raise ValueError(parsed.message)

# helper to use the MCP tool to construct a GDC cohort filter
def get_cohort_filter(query: str) -> str:
    response = requests.post(
        endpoint,
        json=request(
            method="tools/call",
            params={
                "name": "generate_filter",
                "arguments": {
                    "query": query,
                },
            },
        ),
        headers=headers,
    )

    result = parse_sse(response)
    return result["content"][0]["text"]

# helper to convert GDC request to file mapping
def get_file_mapping(cohort_filter):
    df = pd.read_csv(
        StringIO(
            requests.get(
                "https://api.gdc.cancer.gov/files",
                params={
                    "filters": cohort_filter,
                    "fields": ",".join(
                        [
                            "file_name",
                            "cases.project.project_id",
                            "cases.submitter_id",
                            "experimental_strategy",
                            "file_size",
                            "md5sum",
                            "state",
                        ]
                    ),
                    "format": "TSV",
                    "size": str(100_000),
                },
            ).text
        ),
        sep="\t",
    )
    mapping = df[["cases.0.submitter_id", "file_name"]].rename(
        columns={
            "cases.0.submitter_id": "case_id",
        }
    )
    mapping["file_name"] = (
        mapping["file_name"]
        .str.replace(".svs", "")
        .str.replace(".rna_seq.augmented_star_gene_counts.tsv", "")
        .str.replace(".PDF", "")
    )
    return mapping.set_index("case_id")["file_name"]

# %%
# Get the tool list
response = requests.post(
    endpoint,
    json=request(method="tools/list"),
    headers=headers,
)

print(json.dumps(parse_sse(response), indent=4))
# Out:
# {
#     "tools": [
#         {
#             "name": "GDC_Cohort_Copilot_generate_filter",
#             "description": "Converts a free text description of a cancer cohort into a GDC structured cohort filter. Returns: str: JSON structured GDC cohort filter",
#             "inputSchema": {
#                 "type": "object",
#                 "properties": {
#                     "query": {
#                         "type": "string",
#                         "description": "The free text cohort description"
#                     }
#                 }
#             }
#         }
#     ]
# }

# %%
# Construct some cohort filters, you can print these to see what they look like!
hist_filter = get_cohort_filter("TCGA-LUAD samples with diagnostic slides as svs files")
expr_filter = get_cohort_filter("TCGA-LUAD samples with RNA-sequences gene expression quantification data as tsv files")
text_filter = get_cohort_filter("TCGA-LUAD samples with pathology report pdf files")

# %%
print(hist_filter)
print(expr_filter)
print(text_filter)
# Out:
# {
#     "op": "and",
#     "content": [
#         {
#             "op": "in",
#             "content": {
#                 "field": "cases.project.project_id",
#                 "value": [
#                     "TCGA-LUAD"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.experimental_strategy",
#                 "value": [
#                     "Diagnostic Slide"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.data_format",
#                 "value": [
#                     "svs"
#                 ]
#             }
#         }
#     ]
# }
# {
#     "op": "and",
#     "content": [
#         {
#             "op": "in",
#             "content": {
#                 "field": "cases.project.project_id",
#                 "value": [
#                     "TCGA-LUAD"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.data_type",
#                 "value": [
#                     "Gene Expression Quantification"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.experimental_strategy",
#                 "value": [
#                     "RNA-Seq"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.data_format",
#                 "value": [
#                     "tsv"
#                 ]
#             }
#         }
#     ]
# }
# {
#     "op": "and",
#     "content": [
#         {
#             "op": "in",
#             "content": {
#                 "field": "cases.project.project_id",
#                 "value": [
#                     "TCGA-LUAD"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "cases.project.program.name",
#                 "value": [
#                     "TCGA"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.data_type",
#                 "value": [
#                     "Pathology Report"
#                 ]
#             }
#         },
#         {
#             "op": "in",
#             "content": {
#                 "field": "files.data_format",
#                 "value": [
#                     "pdf"
#                 ]
#             }
#         }
#     ]
# }

# %%
# Query the API using the filters to get a mapping of case ID --> filename (from the embedding service)
hist_mapping = get_file_mapping(hist_filter)
expr_mapping = get_file_mapping(expr_filter)
text_mapping = get_file_mapping(text_filter)

# %%
# Get clinical metadata, this is standard code to pull data from the GDC
# (though we use an extra call to the GDC Cohort Copilot for fun)
response = requests.get(
    "https://api.gdc.cancer.gov/cases",
    params={
        "filters": get_cohort_filter("samples from TCGA-LUAD"),
        "fields": ",".join(
            [
                "project.project_id",
                "submitter_id",
                "diagnoses.age_at_diagnosis",
                "diagnoses.diagnosis_is_primary_disease",
                "diagnoses.days_to_last_follow_up",
                "demographic.days_to_death",
                "demographic.vital_status",
                "demographic.ethnicity",
                "demographic.gender",
                "demographic.race",
            ]
        ),
        "format": "JSON",
        "size": str(100_000),
    },
)
temp = json.loads(response.content)

data = []
for sample in temp["data"]["hits"]:
    if "diagnoses" not in sample:
        continue
    for diagnosis in sample["diagnoses"]:
        if "diagnosis_is_primary_disease" in diagnosis and diagnosis["diagnosis_is_primary_disease"]:
            break
    else:
        # no primary disease, skip
        continue
    if "days_to_last_follow_up" not in diagnosis:
        # primary diagnosis does not have f/u
        continue
    data.append({
        "project_id": sample["project"]["project_id"],
        "case_id": sample["submitter_id"],
        "age_at_diagnosis": diagnosis["age_at_diagnosis"],
        "days_to_last_fu": diagnosis["days_to_last_follow_up"],
        "sex": sample["demographic"]["gender"],
        "race": sample["demographic"]["race"],
        "ethnicity": sample["demographic"]["ethnicity"],
        "vital_status": sample["demographic"]["vital_status"],
    })

# %% [markdown]
# #### Merge Embeddings and Metadata

# %%
case_ids = ( # case IDs that have all 3 embedding modalities
    set(expr_mapping[expr_mapping.isin(expr_embs)].index) &
    set(hist_mapping[hist_mapping.isin(hist_embs)].index) &
    set(text_mapping[text_mapping.isin(text_embs)].index)
)

# %%
df = pd.DataFrame(data)
df = df[
    df["case_id"].isin(case_ids)
    & df["vital_status"].isin({"Alive", "Dead"})
    & df["age_at_diagnosis"].notna()
    & df["days_to_last_fu"].notna()
    & (df["days_to_last_fu"] >= 0)
]
df["age_at_diagnosis"] /= 365.24 # convert age to years
df["age_binned"] = pd.cut(df["age_at_diagnosis"], bins=np.arange(0, 101, 20))
df = df.sort_values(["case_id", "age_at_diagnosis"]).reset_index(drop=True)

# %%
expr_X = []
hist_X = []
text_X = []
for _, row in df.iterrows():
    case_id = row["case_id"]
    for embs, mapping, X in [
        (expr_embs, expr_mapping, expr_X),
        (hist_embs, hist_mapping, hist_X),
        (text_embs, text_mapping, text_X),
    ]:
        fnames = mapping.loc[case_id]
        if isinstance(fnames, str):
            emb = embs[fnames] # fname is guaranteed to be in embeddings
        else:
            # at least one fname will be in embs
            emb = np.mean([embs[f] for f in fnames if f in embs], axis=0)
        X.append(emb)
expr_X = np.asarray(expr_X)
hist_X = np.asarray(hist_X)
text_X = np.asarray(text_X)

# %% [markdown]
# #### Prepare Experiments

# %%
demo_X = OneHotEncoder(drop="if_binary", sparse_output=False, dtype=np.float32).fit_transform(df[["sex", "age_binned", "race", "ethnicity"]])
# canc_X = OneHotEncoder(drop="if_binary", sparse_output=False, dtype=np.float32).fit_transform(df[["project_id"]]) # cancer type doesn't change for single project demo

# %%
y = np.array(
    list(zip(df["vital_status"] == "Dead", df["days_to_last_fu"])),
    dtype=[("Status", "?"), ("Survival_in_days", "<f8")],
)

# %%
splitter = ( # stratify by observed mortality and cancer type
    df["vital_status"]
    + df["age_binned"].astype(str)
    + df["project_id"]
)

( # split all data modalities into train/test
    demo_X_train,
    demo_X_test,
    # canc_X_train,
    # canc_X_test,
    expr_X_train,
    expr_X_test,
    hist_X_train,
    hist_X_test,
    text_X_train,
    text_X_test,
    y_train,
    y_test,
) = train_test_split(
    demo_X,
    # canc_X,
    expr_X,
    hist_X,
    text_X,
    y,
    test_size=0.2,
    random_state=42,
    stratify=splitter,
)

# %%
# this one helper will be used to run both unimodal and multimodal experiments
def train_eval_model(
    *,  # enforce kwargs
    X_train: np.ndarray,
    y_train: np.ndarray,
    X_test: np.ndarray,
    y_test: np.ndarray,
    pca_components: Optional[int],
    standardize: bool,
    name: str = "",
    verbose: bool = False,
) -> dict:
    if verbose:
        print(f"Running {name}")

    # z-score input features
    if standardize:
        if verbose:
            print("--standardized")
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
    else:
        X_train_scaled = X_train
        X_test_scaled = X_test

    # dimensionality reduction
    if pca_components is not None:
        if verbose:
            print("--reduced")
        pca = PCA(n_components=pca_components, random_state=42)
        X_train_red = pca.fit_transform(X_train_scaled)
        X_test_red = pca.transform(X_test_scaled)
    else:
        X_train_red = X_train_scaled
        X_test_red = X_test_scaled

    # fit survival model
    cox = CoxPHSurvivalAnalysis(alpha=0.1).fit(X_train_red, y_train)
    if verbose:
        print("--trained")

    # generate predictions
    y_train_pred = cox.predict(X_train_red)
    y_test_pred = cox.predict(X_test_red)

    # evaluate predictions
    c_index = concordance_index_censored(
        event_indicator=y_test["Status"],
        event_time=y_test["Survival_in_days"],
        estimate=y_test_pred,
    )[0]

    return {
        "c_index": c_index,
        "y_test_pred": y_test_pred,
        "y_train_pred": y_train_pred,
        "coxph": cox,
    }

# %% [markdown]
# #### Train Unimodal Models

# %%
demo_results = train_eval_model(X_train=demo_X_train, y_train=y_train, X_test=demo_X_test, y_test=y_test, pca_components=None, standardize=False, name="demo", verbose=True)
# canc_results = train_eval_model(X_train=canc_X_train, y_train=y_train, X_test=canc_X_test, y_test=y_test, pca_components=None, standardize=False, name="canc", verbose=True)
expr_results = train_eval_model(X_train=expr_X_train, y_train=y_train, X_test=expr_X_test, y_test=y_test, pca_components=256, standardize=True, name="expr", verbose=True)
hist_results = train_eval_model(X_train=hist_X_train, y_train=y_train, X_test=hist_X_test, y_test=y_test, pca_components=256, standardize=True, name="hist", verbose=True)
text_results = train_eval_model(X_train=text_X_train, y_train=y_train, X_test=text_X_test, y_test=y_test, pca_components=256, standardize=True, name="text", verbose=True)
# Out:
# Running demo
# --trained
# Running expr
# --standardized
# --reduced
# --trained
# Running hist
# --standardized
# --reduced
# --trained
# Running text
# --standardized
# --reduced
# /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages/sksurv/linear_model/coxph.py:173: RuntimeWarning: overflow encountered in exp
#   risk_set += np.exp(xw[k])
# /opt/gpudata/steven/miniforge3/envs/m3ai-demos/lib/python3.9/site-packages/sksurv/linear_model/coxph.py:170: RuntimeWarning: overflow encountered in exp
#   risk_set2 += np.exp(xw[k])
# --trained

# %% [markdown]
# #### Train Multimodal Model
# The unimodal models' predicted risk scores are used as input to the multimodal fusion model.

# %%
fuse_X_train = np.asarray([
    demo_results["y_train_pred"],
    # canc_results["y_train_pred"],
    expr_results["y_train_pred"],
    hist_results["y_train_pred"],
    text_results["y_train_pred"],
]).T

fuse_X_test = np.asarray([
    demo_results["y_test_pred"],
    # canc_results["y_test_pred"],
    expr_results["y_test_pred"],
    hist_results["y_test_pred"],
    text_results["y_test_pred"],
]).T

fuse_results = train_eval_model(X_train=fuse_X_train, y_train=y_train, X_test=fuse_X_test, y_test=y_test, pca_components=None, standardize=True, name="fuse", verbose=True)
# Out:
# Running fuse
# --standardized
# --trained

# %% [markdown]
# #### Evaluate Models
# Our multimodal fusion approach substantially beats all unimodal results!

# %%
results = pd.Series({
    "demo": demo_results["c_index"],
    # "canc": canc_results["c_index"],
    "expr": expr_results["c_index"],
    "hist": hist_results["c_index"],
    "text": text_results["c_index"],
    "fuse": fuse_results["c_index"],
}, name="C-index")

print("Unimodal Results")
print("------------------")
display(results.loc[["demo", "expr", "hist", "text"]])

print("Multimodal Results")
print("------------------")
display(results.loc[["fuse"]])
# Out:
# Unimodal Results
# ------------------
# demo    0.541131
# expr    0.492716
# hist    0.549272
# text    0.558698
# Name: C-index, dtype: float64
# Multimodal Results
# ------------------
# fuse    0.586975
# Name: C-index, dtype: float64
